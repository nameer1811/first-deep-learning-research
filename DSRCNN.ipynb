# %%
import tensorflow as tf,os,math,numpy as np
from tensorflow.keras import layers
from tensorflow.keras import callbacks as tkc
from tensorflow.keras.preprocessing.image import load_img,array_to_img,img_to_array
from tensorflow.keras.preprocessing import image_dataset_from_directory
from IPython.display import display
import pylab as pl,PIL

def scale01(img): 
    return img/255

def process_input(input_rgb,img_size):
    input_yuv=tf.image.rgb_to_yuv(input_rgb)
    last_dimension_axis=len(input_yuv.shape)-1
    y,u,v=tf.split(input_yuv,3,axis=last_dimension_axis)
    
    return tf.image.resize(y,[img_size,img_size],method='bicubic')

def process_target(input_rgb):
    input_yuv=tf.image.rgb_to_yuv(input_rgb)
    last_dimension_axis=len(input_yuv.shape)-1
    y,u,v=tf.split(input_yuv,3,axis=last_dimension_axis)
    
    return y

train_high_ds = '/home/cst2/preprocessed_data/train/resized_ds'
validate_high_ds = '/home/cst2/preprocessed_data/validate/resized_ds'

[crop_size,upscale_factor]=[200,2]
input_size=crop_size//upscale_factor
batch_size=8

train_ds=image_dataset_from_directory(
    train_high_ds,batch_size=batch_size,
    image_size=(crop_size,crop_size),
    validation_split=.2,subset='training',
    seed=123,label_mode=None,)

valid_ds=image_dataset_from_directory(
    validate_high_ds,batch_size=batch_size,
    image_size=(crop_size,crop_size),
    validation_split=.2,subset='validation',
    seed=1234,label_mode=None,)

train_ds=train_ds.map(scale01)
valid_ds=valid_ds.map(scale01)
        
test_path='/home/cst2/preprocessed_data/test/resized_ds/resized'
test_paths=sorted(
    [os.path.join(test_path,fname) 
    for fname in os.listdir(test_path)
    if fname.endswith('.jpg')])

train_ds=train_ds.map(
    lambda x: (process_input(x,input_size),process_target(x)))
train_ds=train_ds.prefetch(buffer_size=16)

valid_ds=valid_ds.map(
    lambda x: (process_input(x,input_size),process_target(x)))
valid_ds=valid_ds.prefetch(buffer_size=16)

for batch in valid_ds.take(1):
    for img in batch[0]: display(array_to_img(img)); break
    print(10*'==> ')
    for img in batch[1]: display(array_to_img(img)); break
        
def model(upscale_factor=upscale_factor,channels=3):
    conv_args={'activation':'relu',
               'kernel_initializer':'Orthogonal',
               'padding':'same',}
    inputs=tf.keras.Input(shape=(None,None,1))
    x1_1 = layers.Conv2D(256, 5, **conv_args)(inputs)
    x2_1 = layers.Conv2D(96, 3, **conv_args)(x1_1)
    
    x2_2 = layers.Conv2DTranspose(96, 3, **conv_args)(x2_1)
    x2 = layers.Add()([x2_1, x2_2])
        
    x1_2 = layers.Conv2DTranspose(256, 3, **conv_args)(x2)
    x1 = layers.Add()([x1_1, x1_2])
    
    x = layers.Conv2D(32, 3, **conv_args)(x1)
    x = layers.Conv2D(channels * (upscale_factor ** 2), 3, **conv_args)(x)
    outputs=tf.nn.depth_to_space(x,upscale_factor)
    return tf.keras.Model(inputs,outputs)

def display_results(img,prefix,title):
    img_array=img_to_array(img)
    img_array=img_array.astype('float32')/255
    fig,ax=pl.subplots()
    im=ax.imshow(img_array[::-1],origin='lower')
    pl.title(title)
    pl.show()
    
def low_resolution_img(img,upscale_factor):
    dimensions=(img.size[0]//upscale_factor,img.size[1]//upscale_factor)
    
    return img.resize(dimensions,PIL.Image.BICUBIC,)

def upscale_img(model,img):
    ycbcr=img.convert('YCbCr')
    y,cb,cr=ycbcr.split()
    y=img_to_array(y).astype('float32')/255
    input_img=np.expand_dims(y,axis=0)
    out=model.predict(input_img)
    out_img_y=out[0]*255.
    out_img_y=out_img_y.clip(0,255)
    out_img_y=out_img_y.reshape(
        (np.shape(out_img_y)[0],np.shape(out_img_y)[1]))
    out_img_y=PIL.Image.fromarray(np.uint8(out_img_y),mode='L')
    out_img_cb=cb.resize(out_img_y.size,PIL.Image.BICUBIC)
    out_img_cr=cr.resize(out_img_y.size,PIL.Image.BICUBIC)
    out_img=PIL.Image.merge('YCbCr',(out_img_y,out_img_cb,out_img_cr))
    
    return out_img.convert('RGB')

class ESPCNCallback(tf.keras.callbacks.Callback):
    def __init__(self):
        super(ESPCNCallback,self).__init__()
#         self.test_img=low_resolution_img(
#             load_img(test_paths[0]),upscale_factor)
    def on_epoch_begin(self,epoch,logs=None):
        self.psnr=[]
    def on_epoch_end(self,epoch,logs=None):
        print('mean PSNR for epoch: %.2f'%(np.mean(self.psnr)))
        
    def on_test_batch_end(self,batch,logs=None):
        self.psnr.append(10*math.log10(1/logs['loss']))
# Out:
# 2021-11-29 11:06:00.230217: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# Found 8000 files belonging to 1 classes.
# Using 6400 files for training.
# 2021-11-29 11:06:01.398955: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-11-29 11:06:01.399528: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-11-29 11:06:01.498724: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-29 11:06:01.500411: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:09:00.0 name: Quadro RTX 8000 computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 47.46GiB deviceMemoryBandwidth: 625.94GiB/s
# 2021-11-29 11:06:01.500459: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-29 11:06:01.502151: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 1 with properties:
# pciBusID: 0000:0a:00.0 name: Quadro RTX 8000 computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 47.46GiB deviceMemoryBandwidth: 625.94GiB/s
# 2021-11-29 11:06:01.502168: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-11-29 11:06:01.503196: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-11-29 11:06:01.503226: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2021-11-29 11:06:01.504315: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-11-29 11:06:01.504495: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-11-29 11:06:01.505475: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-11-29 11:06:01.506084: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2021-11-29 11:06:01.508339: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-11-29 11:06:01.508461: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-29 11:06:01.510223: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-29 11:06:01.511921: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-29 11:06:01.513587: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-29 11:06:01.515236: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0, 1
# 2021-11-29 11:06:01.515772: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-11-29 11:06:01.704562: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-29 11:06:01.706213: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:09:00.0 name: Quadro RTX 8000 computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 47.46GiB deviceMemoryBandwidth: 625.94GiB/s
# 2021-11-29 11:06:01.706262: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-29 11:06:01.707870: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 1 with properties:
# pciBusID: 0000:0a:00.0 name: Quadro RTX 8000 computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 47.46GiB deviceMemoryBandwidth: 625.94GiB/s
# 2021-11-29 11:06:01.707891: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-11-29 11:06:01.707909: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-11-29 11:06:01.707917: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2021-11-29 11:06:01.707924: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-11-29 11:06:01.707931: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-11-29 11:06:01.707937: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-11-29 11:06:01.707944: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2021-11-29 11:06:01.707951: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-11-29 11:06:01.707990: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-29 11:06:01.709627: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-29 11:06:01.711278: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-29 11:06:01.712936: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-29 11:06:01.714549: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0, 1
# 2021-11-29 11:06:01.714579: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-11-29 11:06:02.384456: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-11-29 11:06:02.384491: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0 1
# 2021-11-29 11:06:02.384496: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N Y
# 2021-11-29 11:06:02.384499: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 1:   Y N
# 2021-11-29 11:06:02.384733: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-29 11:06:02.386434: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-29 11:06:02.388138: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-29 11:06:02.389799: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-29 11:06:02.391422: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 45320 MB memory) -> physical GPU (device: 0, name: Quadro RTX 8000, pci bus id: 0000:09:00.0, compute capability: 7.5)
# 2021-11-29 11:06:02.391734: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-29 11:06:02.393404: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-29 11:06:02.395023: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 45388 MB memory) -> physical GPU (device: 1, name: Quadro RTX 8000, pci bus id: 0000:0a:00.0, compute capability: 7.5)
# 2021-11-29 11:06:02.395171: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# Found 8000 files belonging to 1 classes.
# Using 1600 files for validation.
# 2021-11-29 11:06:03.085224: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-11-29 11:06:03.102911: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 3692605000 Hz
# <PIL.Image.Image image mode=L size=100x100 at 0x7F89600C0370>
# ==> ==> ==> ==> ==> ==> ==> ==> ==> ==>
# <PIL.Image.Image image mode=L size=200x200 at 0x7F89600D66A0>

# %%
early_stopping=tkc.EarlyStopping(monitor='loss',verbose=2,patience=10)

checkpoint_path='/home/cst2/Testing Code/checkpoint/dnsrcnn'
checkpoint=tkc.ModelCheckpoint(
    filepath=checkpoint_path,save_weights_only=True,
    monitor='loss',mode='min',save_best_only=True,verbose=2)

lr_reduction=tkc.ReduceLROnPlateau(
    monitor='val_loss',patience=10,verbose=2,factor=.9)

model=model(upscale_factor=upscale_factor,channels=1)

model.summary()

callbacks=[ESPCNCallback(),early_stopping,checkpoint,lr_reduction]

loss_fn=tf.keras.losses.MeanSquaredError()

optimizer=tf.keras.optimizers.Adam(learning_rate=.0001)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, None, None, 2 6656        input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, None, None, 9 221280      conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, None, None, 9 83040       conv2d_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, None, None, 9 0           conv2d_1[0][0]
#                                                                  conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, None, None, 2 221440      add[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, None, None, 2 0           conv2d[0][0]
#                                                                  conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, None, None, 3 73760       add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, None, None, 4 1156        conv2d_2[0][0]
# __________________________________________________________________________________________________
# tf.nn.depth_to_space (TFOpLambd (None, None, None, 1 0           conv2d_3[0][0]
# ==================================================================================================
# Total params: 607,332
# Trainable params: 607,332
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
epochs=50

model.compile(optimizer=optimizer,loss=loss_fn,metrics=['accuracy'],)

history=model.fit(train_ds,epochs=epochs,callbacks=callbacks,validation_data=valid_ds,verbose=2)

model.load_weights(checkpoint_path)
# Out:
# Epoch 1/50
# 2021-11-29 11:06:17.772356: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-11-29 11:06:18.697227: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 800/800 - 24s - loss: 0.0117 - accuracy: 0.0044 - val_loss: 7.5177e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 31.16
#
# Epoch 00001: loss improved from inf to 0.01166, saving model to /home/cst2/Testing Code/checkpoint/dnsrcnn
# Epoch 2/50
# 800/800 - 22s - loss: 7.1683e-04 - accuracy: 0.0045 - val_loss: 6.9405e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 31.46
#
# Epoch 00002: loss improved from 0.01166 to 0.00072, saving model to /home/cst2/Testing Code/checkpoint/dnsrcnn
# Epoch 3/50
# 800/800 - 22s - loss: 6.8610e-04 - accuracy: 0.0045 - val_loss: 6.6425e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 31.64
#
# Epoch 00003: loss improved from 0.00072 to 0.00069, saving model to /home/cst2/Testing Code/checkpoint/dnsrcnn
# Epoch 4/50
# 800/800 - 23s - loss: 6.4348e-04 - accuracy: 0.0045 - val_loss: 6.3818e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 31.89
#
# Epoch 00004: loss improved from 0.00069 to 0.00064, saving model to /home/cst2/Testing Code/checkpoint/dnsrcnn
# Epoch 5/50
# 800/800 - 23s - loss: 6.2752e-04 - accuracy: 0.0045 - val_loss: 6.2219e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 31.94
#
# Epoch 00005: loss improved from 0.00064 to 0.00063, saving model to /home/cst2/Testing Code/checkpoint/dnsrcnn
# Epoch 6/50
# 800/800 - 23s - loss: 6.1137e-04 - accuracy: 0.0045 - val_loss: 6.0959e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 32.03
#
# Epoch 00006: loss improved from 0.00063 to 0.00061, saving model to /home/cst2/Testing Code/checkpoint/dnsrcnn
# Epoch 7/50
# 800/800 - 23s - loss: 6.0350e-04 - accuracy: 0.0045 - val_loss: 6.0298e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 32.08
#
# Epoch 00007: loss improved from 0.00061 to 0.00060, saving model to /home/cst2/Testing Code/checkpoint/dnsrcnn
# Epoch 8/50
# 800/800 - 23s - loss: 5.9515e-04 - accuracy: 0.0045 - val_loss: 5.9839e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 32.14
#
# Epoch 00008: loss improved from 0.00060 to 0.00060, saving model to /home/cst2/Testing Code/checkpoint/dnsrcnn
# Epoch 9/50
# 800/800 - 23s - loss: 5.9796e-04 - accuracy: 0.0045 - val_loss: 5.9277e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 32.17
#
# Epoch 00009: loss did not improve from 0.00060
# Epoch 10/50
# 800/800 - 23s - loss: 5.8244e-04 - accuracy: 0.0045 - val_loss: 5.8867e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 32.17
#
# Epoch 00010: loss improved from 0.00060 to 0.00058, saving model to /home/cst2/Testing Code/checkpoint/dnsrcnn
# Epoch 11/50
# 800/800 - 23s - loss: 5.8331e-04 - accuracy: 0.0045 - val_loss: 5.8603e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 32.23
#
# Epoch 00011: loss did not improve from 0.00058
# Epoch 12/50
# 800/800 - 23s - loss: 5.7561e-04 - accuracy: 0.0045 - val_loss: 5.8225e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 32.25
#
# Epoch 00012: loss improved from 0.00058 to 0.00058, saving model to /home/cst2/Testing Code/checkpoint/dnsrcnn
# Epoch 13/50
# 800/800 - 23s - loss: 5.7627e-04 - accuracy: 0.0045 - val_loss: 5.7913e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 32.30
#
# Epoch 00013: loss did not improve from 0.00058
# Epoch 14/50
# 800/800 - 23s - loss: 5.7160e-04 - accuracy: 0.0045 - val_loss: 5.8317e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 32.20
#
# Epoch 00014: loss improved from 0.00058 to 0.00057, saving model to /home/cst2/Testing Code/checkpoint/dnsrcnn
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 8.999999772640876e-05.
# Epoch 15/50
# 800/800 - 23s - loss: 5.6746e-04 - accuracy: 0.0045 - val_loss: 5.7501e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 32.29
#
# Epoch 00015: loss improved from 0.00057 to 0.00057, saving model to /home/cst2/Testing Code/checkpoint/dnsrcnn
# Epoch 16/50
# 800/800 - 23s - loss: 5.6677e-04 - accuracy: 0.0045 - val_loss: 5.7328e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 32.28
#
# Epoch 00016: loss improved from 0.00057 to 0.00057, saving model to /home/cst2/Testing Code/checkpoint/dnsrcnn
# Epoch 17/50
# 800/800 - 23s - loss: 5.6426e-04 - accuracy: 0.0045 - val_loss: 5.7315e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 32.28
#
# Epoch 00017: loss improved from 0.00057 to 0.00056, saving model to /home/cst2/Testing Code/checkpoint/dnsrcnn
# Epoch 18/50
# 800/800 - 23s - loss: 5.6232e-04 - accuracy: 0.0045 - val_loss: 5.6967e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 32.32
#
# Epoch 00018: loss improved from 0.00056 to 0.00056, saving model to /home/cst2/Testing Code/checkpoint/dnsrcnn
# Epoch 19/50
# 800/800 - 23s - loss: 5.6036e-04 - accuracy: 0.0045 - val_loss: 5.6705e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 32.39
#
# Epoch 00019: loss improved from 0.00056 to 0.00056, saving model to /home/cst2/Testing Code/checkpoint/dnsrcnn
# Epoch 20/50
# 800/800 - 23s - loss: 5.5890e-04 - accuracy: 0.0045 - val_loss: 5.7310e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 32.29
#
# Epoch 00020: loss improved from 0.00056 to 0.00056, saving model to /home/cst2/Testing Code/checkpoint/dnsrcnn
# Epoch 21/50
# 800/800 - 23s - loss: 5.5731e-04 - accuracy: 0.0045 - val_loss: 5.6499e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 32.37
#
# Epoch 00021: loss improved from 0.00056 to 0.00056, saving model to /home/cst2/Testing Code/checkpoint/dnsrcnn
# Epoch 22/50
# 800/800 - 23s - loss: 5.5618e-04 - accuracy: 0.0045 - val_loss: 5.6375e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 32.35
#
# Epoch 00022: loss improved from 0.00056 to 0.00056, saving model to /home/cst2/Testing Code/checkpoint/dnsrcnn
# Epoch 23/50
# 800/800 - 23s - loss: 5.5587e-04 - accuracy: 0.0045 - val_loss: 5.6384e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 32.35
#
# Epoch 00023: loss improved from 0.00056 to 0.00056, saving model to /home/cst2/Testing Code/checkpoint/dnsrcnn
# Epoch 24/50
# 800/800 - 23s - loss: 5.5219e-04 - accuracy: 0.0045 - val_loss: 5.6149e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 32.37
#
# Epoch 00024: loss improved from 0.00056 to 0.00055, saving model to /home/cst2/Testing Code/checkpoint/dnsrcnn
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 8.100000122794882e-05.
# Epoch 25/50
# 800/800 - 23s - loss: 5.5095e-04 - accuracy: 0.0045 - val_loss: 5.6062e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 32.42
#
# Epoch 00025: loss improved from 0.00055 to 0.00055, saving model to /home/cst2/Testing Code/checkpoint/dnsrcnn
# Epoch 26/50
# 800/800 - 23s - loss: 5.5152e-04 - accuracy: 0.0045 - val_loss: 5.6029e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 32.42
#
# Epoch 00026: loss did not improve from 0.00055
# Epoch 27/50
# 800/800 - 23s - loss: 5.4887e-04 - accuracy: 0.0045 - val_loss: 5.5918e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 32.43
#
# Epoch 00027: loss improved from 0.00055 to 0.00055, saving model to /home/cst2/Testing Code/checkpoint/dnsrcnn
# Epoch 28/50
# 800/800 - 23s - loss: 5.4832e-04 - accuracy: 0.0045 - val_loss: 5.5635e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 32.45
#
# Epoch 00028: loss improved from 0.00055 to 0.00055, saving model to /home/cst2/Testing Code/checkpoint/dnsrcnn
# Epoch 29/50
# 800/800 - 23s - loss: 5.4675e-04 - accuracy: 0.0045 - val_loss: 5.5602e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 32.43
#
# Epoch 00029: loss improved from 0.00055 to 0.00055, saving model to /home/cst2/Testing Code/checkpoint/dnsrcnn
# Epoch 30/50
# 800/800 - 23s - loss: 5.4668e-04 - accuracy: 0.0045 - val_loss: 5.5851e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 32.39
#
# Epoch 00030: loss improved from 0.00055 to 0.00055, saving model to /home/cst2/Testing Code/checkpoint/dnsrcnn
# Epoch 31/50
# 800/800 - 23s - loss: 5.4573e-04 - accuracy: 0.0045 - val_loss: 5.5453e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 32.46
#
# Epoch 00031: loss improved from 0.00055 to 0.00055, saving model to /home/cst2/Testing Code/checkpoint/dnsrcnn
# Epoch 32/50
# 800/800 - 23s - loss: 5.4433e-04 - accuracy: 0.0045 - val_loss: 5.5600e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 32.43
#
# Epoch 00032: loss improved from 0.00055 to 0.00054, saving model to /home/cst2/Testing Code/checkpoint/dnsrcnn
# Epoch 33/50
# 800/800 - 23s - loss: 5.4401e-04 - accuracy: 0.0045 - val_loss: 5.5448e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 32.46
#
# Epoch 00033: loss improved from 0.00054 to 0.00054, saving model to /home/cst2/Testing Code/checkpoint/dnsrcnn
# Epoch 34/50
# 800/800 - 23s - loss: 5.4297e-04 - accuracy: 0.0045 - val_loss: 5.5262e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 32.43
#
# Epoch 00034: loss improved from 0.00054 to 0.00054, saving model to /home/cst2/Testing Code/checkpoint/dnsrcnn
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 7.289999848580919e-05.
# Epoch 35/50
# 800/800 - 23s - loss: 5.4174e-04 - accuracy: 0.0045 - val_loss: 5.5279e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 32.50
#
# Epoch 00035: loss improved from 0.00054 to 0.00054, saving model to /home/cst2/Testing Code/checkpoint/dnsrcnn
# Epoch 36/50
# 800/800 - 23s - loss: 5.4117e-04 - accuracy: 0.0045 - val_loss: 5.5116e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 32.48
#
# Epoch 00036: loss improved from 0.00054 to 0.00054, saving model to /home/cst2/Testing Code/checkpoint/dnsrcnn
# Epoch 37/50
# 800/800 - 23s - loss: 5.4042e-04 - accuracy: 0.0045 - val_loss: 5.5106e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 32.45
#
# Epoch 00037: loss improved from 0.00054 to 0.00054, saving model to /home/cst2/Testing Code/checkpoint/dnsrcnn
# Epoch 38/50
# 800/800 - 23s - loss: 5.3997e-04 - accuracy: 0.0045 - val_loss: 5.5126e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 32.45
#
# Epoch 00038: loss improved from 0.00054 to 0.00054, saving model to /home/cst2/Testing Code/checkpoint/dnsrcnn
# Epoch 39/50
# 800/800 - 23s - loss: 5.3889e-04 - accuracy: 0.0045 - val_loss: 5.5051e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 32.49
#
# Epoch 00039: loss improved from 0.00054 to 0.00054, saving model to /home/cst2/Testing Code/checkpoint/dnsrcnn
# Epoch 40/50
# 800/800 - 23s - loss: 5.3891e-04 - accuracy: 0.0045 - val_loss: 5.4967e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 32.48
#
# Epoch 00040: loss did not improve from 0.00054
# Epoch 41/50
# 800/800 - 23s - loss: 5.3784e-04 - accuracy: 0.0045 - val_loss: 5.4820e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 32.54
#
# Epoch 00041: loss improved from 0.00054 to 0.00054, saving model to /home/cst2/Testing Code/checkpoint/dnsrcnn
# Epoch 42/50
# 800/800 - 23s - loss: 5.3734e-04 - accuracy: 0.0045 - val_loss: 5.5179e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 32.48
#
# Epoch 00042: loss improved from 0.00054 to 0.00054, saving model to /home/cst2/Testing Code/checkpoint/dnsrcnn
# Epoch 43/50
# 800/800 - 23s - loss: 5.3692e-04 - accuracy: 0.0045 - val_loss: 5.4839e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 32.54
#
# Epoch 00043: loss improved from 0.00054 to 0.00054, saving model to /home/cst2/Testing Code/checkpoint/dnsrcnn
# Epoch 44/50
# 800/800 - 23s - loss: 5.3633e-04 - accuracy: 0.0045 - val_loss: 5.4806e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 32.50
#
# Epoch 00044: loss improved from 0.00054 to 0.00054, saving model to /home/cst2/Testing Code/checkpoint/dnsrcnn
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 6.56100019114092e-05.
# Epoch 45/50
# 800/800 - 23s - loss: 5.3547e-04 - accuracy: 0.0045 - val_loss: 5.4697e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 32.53
#
# Epoch 00045: loss improved from 0.00054 to 0.00054, saving model to /home/cst2/Testing Code/checkpoint/dnsrcnn
# Epoch 46/50
# 800/800 - 23s - loss: 5.3481e-04 - accuracy: 0.0045 - val_loss: 5.4940e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 32.49
#
# Epoch 00046: loss improved from 0.00054 to 0.00053, saving model to /home/cst2/Testing Code/checkpoint/dnsrcnn
# Epoch 47/50
# 800/800 - 23s - loss: 5.3483e-04 - accuracy: 0.0045 - val_loss: 5.4610e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 32.52
#
# Epoch 00047: loss did not improve from 0.00053
# Epoch 48/50
# 800/800 - 23s - loss: 5.3396e-04 - accuracy: 0.0045 - val_loss: 5.4642e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 32.50
#
# Epoch 00048: loss improved from 0.00053 to 0.00053, saving model to /home/cst2/Testing Code/checkpoint/dnsrcnn
# Epoch 49/50
# 800/800 - 23s - loss: 5.3380e-04 - accuracy: 0.0045 - val_loss: 5.4618e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 32.51
#
# Epoch 00049: loss improved from 0.00053 to 0.00053, saving model to /home/cst2/Testing Code/checkpoint/dnsrcnn
# Epoch 50/50
# 800/800 - 23s - loss: 5.3324e-04 - accuracy: 0.0045 - val_loss: 5.4535e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 32.50
#
# Epoch 00050: loss improved from 0.00053 to 0.00053, saving model to /home/cst2/Testing Code/checkpoint/dnsrcnn

# %%
total_bicubic_psnr=0.
total_test_psnr=0.
n_img= 10

for index,test_path in enumerate(test_paths[0:n_img]):
    
    img=load_img(test_path)
    lowres_input=low_resolution_img(img,upscale_factor)
    
    w=lowres_input.size[0]*upscale_factor
    h=lowres_input.size[1]*upscale_factor
    
    highres_img=img.resize((w,h))
    
    predict_img=upscale_img(model,lowres_input)
    
    lowres_img=lowres_input.resize((w,h))
    lowres_img_arr=img_to_array(lowres_img)
    
    highres_img_arr=img_to_array(highres_img)
    
    predict_img_arr=img_to_array(predict_img)
    
    bicubic_psnr=tf.image.psnr(lowres_img_arr,highres_img_arr,max_val=255)
    test_psnr=tf.image.psnr(predict_img_arr,highres_img_arr,max_val=255)
    
    total_bicubic_psnr+=bicubic_psnr
    total_test_psnr+=test_psnr
    
    print('PSNR of low resolution and high resolution is %.4f'%bicubic_psnr)
    
    print('PSNR of predict and high resolution is %.4f'%test_psnr)
    
    display_results(lowres_img,index,'low resolution')
    display_results(highres_img,index,'high resolution')
    display_results(predict_img,index,'prediction')
    
print('avg. PSNR of images with low resolution is %.4f'%(total_bicubic_psnr/n_img))

print('avg. PSNR of reconstructions is %.4f'%(total_test_psnr/n_img))
# Out:
# avg. PSNR of images with low resolution is 30.1063
# avg. PSNR of reconstructions is 30.4671
