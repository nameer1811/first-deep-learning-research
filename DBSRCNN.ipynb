# %%
import tensorflow as tf,os,math,numpy as np
from tensorflow.keras import layers
from tensorflow.keras import callbacks as tkc
from tensorflow.keras.preprocessing.image import load_img,array_to_img,img_to_array
from tensorflow.keras.preprocessing import image_dataset_from_directory
from IPython.display import display
import pylab as pl,PIL

def scale01(img): 
    return img/255

def process_input(input_rgb,img_size):
    input_yuv=tf.image.rgb_to_yuv(input_rgb)
    last_dimension_axis=len(input_yuv.shape)-1
    y,u,v=tf.split(input_yuv,3,axis=last_dimension_axis)
    
    return tf.image.resize(y,[img_size,img_size],method='bicubic')

def process_target(input_rgb):
    input_yuv=tf.image.rgb_to_yuv(input_rgb)
    last_dimension_axis=len(input_yuv.shape)-1
    y,u,v=tf.split(input_yuv,3,axis=last_dimension_axis)
    
    return y

train_high_ds = '/home/cst2/preprocessed_data/train/resized_ds'
validate_high_ds = '/home/cst2/preprocessed_data/validate/resized_ds'

[crop_size,upscale_factor]=[200,2]
input_size=crop_size//upscale_factor
batch_size=8

train_ds=image_dataset_from_directory(
    train_high_ds,batch_size=batch_size,
    image_size=(crop_size,crop_size),
    validation_split=.2,subset='training',
    seed=123,label_mode=None,)

valid_ds=image_dataset_from_directory(
    validate_high_ds,batch_size=batch_size,
    image_size=(crop_size,crop_size),
    validation_split=.2,subset='validation',
    seed=1234,label_mode=None,)

train_ds=train_ds.map(scale01)
valid_ds=valid_ds.map(scale01)
        
test_path='/home/cst2/preprocessed_data/test/resized_ds/resized'
test_paths=sorted(
    [os.path.join(test_path,fname) 
    for fname in os.listdir(test_path)
    if fname.endswith('.jpg')])

train_ds=train_ds.map(
    lambda x: (process_input(x,input_size),process_target(x)))
train_ds=train_ds.prefetch(buffer_size=16)

valid_ds=valid_ds.map(
    lambda x: (process_input(x,input_size),process_target(x)))
valid_ds=valid_ds.prefetch(buffer_size=16)

for batch in valid_ds.take(1):
    for img in batch[0]: display(array_to_img(img)); break
    print(10*'==> ')
    for img in batch[1]: display(array_to_img(img)); break
        
def model(upscale_factor=upscale_factor,channels=1):

    inputs=tf.keras.Input(shape=(None,None,1))
    c1 = layers.Convolution2D(32, (9, 9), padding="same", kernel_initializer="he_normal", activation="relu")(inputs)
    c2 = layers.Convolution2D(32, (5, 5), padding="same", kernel_initializer="he_normal", activation="relu")(c1)
    m = layers.concatenate([c1, c2])
    c3 = layers.Convolution2D(32, (5, 5), padding="same", kernel_initializer="he_normal", activation="relu")(m)
    c4 = layers.Convolution2D(32, (5, 5), padding="same", kernel_initializer="he_normal", activation="relu")(c3)
    c5 = layers.Convolution2D(channels*(upscale_factor**2), (5, 5), padding="same", kernel_initializer="he_normal")(c4)
    outputs=tf.nn.depth_to_space(c5,upscale_factor)
    
    return tf.keras.Model(inputs,outputs)

def display_results(img,prefix,title):
    img_array=img_to_array(img)
    img_array=img_array.astype('float32')/255
    fig,ax=pl.subplots()
    im=ax.imshow(img_array[::-1],origin='lower')
    pl.title(title)
    pl.show()
    
def low_resolution_img(img,upscale_factor):
    dimensions=(img.size[0]//upscale_factor,img.size[1]//upscale_factor)
    
    return img.resize(dimensions,PIL.Image.BICUBIC,)

def upscale_img(model,img):
    ycbcr=img.convert('YCbCr')
    y,cb,cr=ycbcr.split()
    y=img_to_array(y).astype('float32')/255
    input_img=np.expand_dims(y,axis=0)
    out=model.predict(input_img)
    out_img_y=out[0]*255.
    out_img_y=out_img_y.clip(0,255)
    out_img_y=out_img_y.reshape(
        (np.shape(out_img_y)[0],np.shape(out_img_y)[1]))
    out_img_y=PIL.Image.fromarray(np.uint8(out_img_y),mode='L')
    out_img_cb=cb.resize(out_img_y.size,PIL.Image.BICUBIC)
    out_img_cr=cr.resize(out_img_y.size,PIL.Image.BICUBIC)
    out_img=PIL.Image.merge('YCbCr',(out_img_y,out_img_cb,out_img_cr))
    
    return out_img.convert('RGB')

class ESPCNCallback(tf.keras.callbacks.Callback):
    def __init__(self):
        super(ESPCNCallback,self).__init__()
        
    def on_epoch_begin(self,epoch,logs=None):
        self.psnr=[]
        
    def on_epoch_end(self,epoch,logs=None):
        print('mean PSNR for epoch: %.2f'%(np.mean(self.psnr)))
        
    def on_test_batch_end(self,batch,logs=None):
        self.psnr.append(10*math.log10(1/logs['loss']))
# Out:
# 2021-11-29 12:18:44.362168: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# Found 8000 files belonging to 1 classes.
# Using 6400 files for training.
# 2021-11-29 12:18:45.482899: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-11-29 12:18:45.483457: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-11-29 12:18:45.602423: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-29 12:18:45.604136: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:09:00.0 name: Quadro RTX 8000 computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 47.46GiB deviceMemoryBandwidth: 625.94GiB/s
# 2021-11-29 12:18:45.604185: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-29 12:18:45.605841: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 1 with properties:
# pciBusID: 0000:0a:00.0 name: Quadro RTX 8000 computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 47.46GiB deviceMemoryBandwidth: 625.94GiB/s
# 2021-11-29 12:18:45.605853: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-11-29 12:18:45.606866: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-11-29 12:18:45.606894: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2021-11-29 12:18:45.607969: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-11-29 12:18:45.608146: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-11-29 12:18:45.609157: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-11-29 12:18:45.609727: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2021-11-29 12:18:45.611962: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-11-29 12:18:45.612077: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-29 12:18:45.613820: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-29 12:18:45.615511: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-29 12:18:45.617192: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-29 12:18:45.618865: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0, 1
# 2021-11-29 12:18:45.619740: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-11-29 12:18:45.787105: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-29 12:18:45.788785: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:09:00.0 name: Quadro RTX 8000 computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 47.46GiB deviceMemoryBandwidth: 625.94GiB/s
# 2021-11-29 12:18:45.788836: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-29 12:18:45.790447: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 1 with properties:
# pciBusID: 0000:0a:00.0 name: Quadro RTX 8000 computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 47.46GiB deviceMemoryBandwidth: 625.94GiB/s
# 2021-11-29 12:18:45.790466: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-11-29 12:18:45.790486: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-11-29 12:18:45.790493: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2021-11-29 12:18:45.790500: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-11-29 12:18:45.790507: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-11-29 12:18:45.790514: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-11-29 12:18:45.790520: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2021-11-29 12:18:45.790527: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-11-29 12:18:45.790566: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-29 12:18:45.792375: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-29 12:18:45.794027: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-29 12:18:45.795683: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-29 12:18:45.797294: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0, 1
# 2021-11-29 12:18:45.797319: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-11-29 12:18:46.442247: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-11-29 12:18:46.442281: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0 1
# 2021-11-29 12:18:46.442286: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N Y
# 2021-11-29 12:18:46.442289: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 1:   Y N
# 2021-11-29 12:18:46.442528: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-29 12:18:46.444239: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-29 12:18:46.445895: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-29 12:18:46.447564: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-29 12:18:46.449200: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 45320 MB memory) -> physical GPU (device: 0, name: Quadro RTX 8000, pci bus id: 0000:09:00.0, compute capability: 7.5)
# 2021-11-29 12:18:46.449510: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-29 12:18:46.451167: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-29 12:18:46.452792: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 45388 MB memory) -> physical GPU (device: 1, name: Quadro RTX 8000, pci bus id: 0000:0a:00.0, compute capability: 7.5)
# 2021-11-29 12:18:46.452952: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# Found 8000 files belonging to 1 classes.
# Using 1600 files for validation.
# 2021-11-29 12:18:47.133046: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-11-29 12:18:47.151040: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 3692605000 Hz
# <PIL.Image.Image image mode=L size=100x100 at 0x7F235425D580>
# ==> ==> ==> ==> ==> ==> ==> ==> ==> ==>
# <PIL.Image.Image image mode=L size=200x200 at 0x7F235425D580>

# %%
early_stopping=tkc.EarlyStopping(monitor='loss',verbose=2,patience=10)

checkpoint_path='/home/cst2/Testing Code/checkpoint/dbsrcnn'
checkpoint=tkc.ModelCheckpoint(
    filepath=checkpoint_path,save_weights_only=True,
    monitor='loss',mode='min',save_best_only=True,verbose=2)

lr_reduction=tkc.ReduceLROnPlateau(
    monitor='val_loss',patience=10,verbose=2,factor=.9)

model=model(upscale_factor=upscale_factor,channels=1)

model.summary()

callbacks=[ESPCNCallback(),early_stopping,checkpoint,lr_reduction]

loss_fn=tf.keras.losses.MeanSquaredError()

optimizer=tf.keras.optimizers.Adam(learning_rate=.0001)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, None, None, 3 2624        input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, None, None, 3 25632       conv2d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, None, None, 6 0           conv2d[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, None, None, 3 51232       concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, None, None, 3 25632       conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, None, None, 4 3204        conv2d_3[0][0]
# __________________________________________________________________________________________________
# tf.nn.depth_to_space (TFOpLambd (None, None, None, 1 0           conv2d_4[0][0]
# ==================================================================================================
# Total params: 108,324
# Trainable params: 108,324
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
epochs=50

model.compile(optimizer=optimizer,loss=loss_fn,metrics=['accuracy'])

history=model.fit(train_ds,epochs=epochs,callbacks=callbacks,validation_data=valid_ds,verbose=2)

model.load_weights(checkpoint_path)
# Out:
# Epoch 1/50
# 2021-11-29 12:19:01.727524: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-11-29 12:19:02.624997: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 800/800 - 16s - loss: 0.0153 - accuracy: 0.0044 - val_loss: 0.0019 - val_accuracy: 0.0042
# mean PSNR for epoch: 27.16
#
# Epoch 00001: loss improved from inf to 0.01534, saving model to /home/cst2/Testing Code/checkpoint/dbsrcnn
# Epoch 2/50
# 800/800 - 15s - loss: 0.0015 - accuracy: 0.0045 - val_loss: 0.0013 - val_accuracy: 0.0042
# mean PSNR for epoch: 28.75
#
# Epoch 00002: loss improved from 0.01534 to 0.00153, saving model to /home/cst2/Testing Code/checkpoint/dbsrcnn
# Epoch 3/50
# 800/800 - 15s - loss: 0.0012 - accuracy: 0.0045 - val_loss: 0.0011 - val_accuracy: 0.0042
# mean PSNR for epoch: 29.38
#
# Epoch 00003: loss improved from 0.00153 to 0.00121, saving model to /home/cst2/Testing Code/checkpoint/dbsrcnn
# Epoch 4/50
# 800/800 - 15s - loss: 0.0011 - accuracy: 0.0045 - val_loss: 0.0010 - val_accuracy: 0.0042
# mean PSNR for epoch: 29.87
#
# Epoch 00004: loss improved from 0.00121 to 0.00107, saving model to /home/cst2/Testing Code/checkpoint/dbsrcnn
# Epoch 5/50
# 800/800 - 15s - loss: 9.9727e-04 - accuracy: 0.0045 - val_loss: 9.4989e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 30.12
#
# Epoch 00005: loss improved from 0.00107 to 0.00100, saving model to /home/cst2/Testing Code/checkpoint/dbsrcnn
# Epoch 6/50
# 800/800 - 15s - loss: 9.3896e-04 - accuracy: 0.0045 - val_loss: 8.9729e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 30.37
#
# Epoch 00006: loss improved from 0.00100 to 0.00094, saving model to /home/cst2/Testing Code/checkpoint/dbsrcnn
# Epoch 7/50
# 800/800 - 15s - loss: 8.7129e-04 - accuracy: 0.0045 - val_loss: 8.5442e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 30.59
#
# Epoch 00007: loss improved from 0.00094 to 0.00087, saving model to /home/cst2/Testing Code/checkpoint/dbsrcnn
# Epoch 8/50
# 800/800 - 15s - loss: 8.5465e-04 - accuracy: 0.0045 - val_loss: 8.2402e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 30.77
#
# Epoch 00008: loss improved from 0.00087 to 0.00085, saving model to /home/cst2/Testing Code/checkpoint/dbsrcnn
# Epoch 9/50
# 800/800 - 15s - loss: 8.1472e-04 - accuracy: 0.0045 - val_loss: 7.9772e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 30.89
#
# Epoch 00009: loss improved from 0.00085 to 0.00081, saving model to /home/cst2/Testing Code/checkpoint/dbsrcnn
# Epoch 10/50
# 800/800 - 15s - loss: 7.8856e-04 - accuracy: 0.0045 - val_loss: 7.7811e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 30.98
#
# Epoch 00010: loss improved from 0.00081 to 0.00079, saving model to /home/cst2/Testing Code/checkpoint/dbsrcnn
# Epoch 11/50
# 800/800 - 15s - loss: 7.7145e-04 - accuracy: 0.0045 - val_loss: 7.6304e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 31.10
#
# Epoch 00011: loss improved from 0.00079 to 0.00077, saving model to /home/cst2/Testing Code/checkpoint/dbsrcnn
# Epoch 12/50
# 800/800 - 15s - loss: 7.6415e-04 - accuracy: 0.0045 - val_loss: 7.5321e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 31.14
#
# Epoch 00012: loss improved from 0.00077 to 0.00076, saving model to /home/cst2/Testing Code/checkpoint/dbsrcnn
# Epoch 13/50
# 800/800 - 15s - loss: 7.5110e-04 - accuracy: 0.0045 - val_loss: 7.4124e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 31.23
#
# Epoch 00013: loss improved from 0.00076 to 0.00075, saving model to /home/cst2/Testing Code/checkpoint/dbsrcnn
# Epoch 14/50
# 800/800 - 15s - loss: 7.4476e-04 - accuracy: 0.0045 - val_loss: 7.3410e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 31.21
#
# Epoch 00014: loss improved from 0.00075 to 0.00074, saving model to /home/cst2/Testing Code/checkpoint/dbsrcnn
# Epoch 15/50
# 800/800 - 15s - loss: 7.2909e-04 - accuracy: 0.0045 - val_loss: 7.2732e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 31.28
#
# Epoch 00015: loss improved from 0.00074 to 0.00073, saving model to /home/cst2/Testing Code/checkpoint/dbsrcnn
# Epoch 16/50
# 800/800 - 15s - loss: 7.2762e-04 - accuracy: 0.0045 - val_loss: 7.2159e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 31.30
#
# Epoch 00016: loss improved from 0.00073 to 0.00073, saving model to /home/cst2/Testing Code/checkpoint/dbsrcnn
# Epoch 17/50
# 800/800 - 15s - loss: 7.2126e-04 - accuracy: 0.0045 - val_loss: 7.1613e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 31.32
#
# Epoch 00017: loss improved from 0.00073 to 0.00072, saving model to /home/cst2/Testing Code/checkpoint/dbsrcnn
# Epoch 18/50
# 800/800 - 15s - loss: 7.1444e-04 - accuracy: 0.0045 - val_loss: 7.1148e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 31.37
#
# Epoch 00018: loss improved from 0.00072 to 0.00071, saving model to /home/cst2/Testing Code/checkpoint/dbsrcnn
# Epoch 19/50
# 800/800 - 15s - loss: 7.1398e-04 - accuracy: 0.0045 - val_loss: 7.0791e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 31.42
#
# Epoch 00019: loss improved from 0.00071 to 0.00071, saving model to /home/cst2/Testing Code/checkpoint/dbsrcnn
# Epoch 20/50
# 800/800 - 15s - loss: 7.1314e-04 - accuracy: 0.0045 - val_loss: 7.0494e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 31.39
#
# Epoch 00020: loss improved from 0.00071 to 0.00071, saving model to /home/cst2/Testing Code/checkpoint/dbsrcnn
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 8.999999772640876e-05.
# Epoch 21/50
# 800/800 - 15s - loss: 6.9734e-04 - accuracy: 0.0045 - val_loss: 7.0121e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 31.44
#
# Epoch 00021: loss improved from 0.00071 to 0.00070, saving model to /home/cst2/Testing Code/checkpoint/dbsrcnn
# Epoch 22/50
# 800/800 - 15s - loss: 7.0376e-04 - accuracy: 0.0045 - val_loss: 7.0385e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 31.40
#
# Epoch 00022: loss did not improve from 0.00070
# Epoch 23/50
# 800/800 - 15s - loss: 6.9690e-04 - accuracy: 0.0045 - val_loss: 6.9593e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 31.45
#
# Epoch 00023: loss improved from 0.00070 to 0.00070, saving model to /home/cst2/Testing Code/checkpoint/dbsrcnn
# Epoch 24/50
# 800/800 - 15s - loss: 6.9246e-04 - accuracy: 0.0045 - val_loss: 6.9315e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 31.46
#
# Epoch 00024: loss improved from 0.00070 to 0.00069, saving model to /home/cst2/Testing Code/checkpoint/dbsrcnn
# Epoch 25/50
# 800/800 - 15s - loss: 6.8978e-04 - accuracy: 0.0045 - val_loss: 6.9226e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 31.51
#
# Epoch 00025: loss improved from 0.00069 to 0.00069, saving model to /home/cst2/Testing Code/checkpoint/dbsrcnn
# Epoch 26/50
# 800/800 - 15s - loss: 6.9560e-04 - accuracy: 0.0045 - val_loss: 6.8897e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 31.54
#
# Epoch 00026: loss did not improve from 0.00069
# Epoch 27/50
# 800/800 - 15s - loss: 6.8087e-04 - accuracy: 0.0045 - val_loss: 6.8618e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 31.54
#
# Epoch 00027: loss improved from 0.00069 to 0.00068, saving model to /home/cst2/Testing Code/checkpoint/dbsrcnn
# Epoch 28/50
# 800/800 - 15s - loss: 6.8524e-04 - accuracy: 0.0045 - val_loss: 6.8391e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 31.56
#
# Epoch 00028: loss did not improve from 0.00068
# Epoch 29/50
# 800/800 - 15s - loss: 6.7845e-04 - accuracy: 0.0045 - val_loss: 6.8080e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 31.56
#
# Epoch 00029: loss improved from 0.00068 to 0.00068, saving model to /home/cst2/Testing Code/checkpoint/dbsrcnn
# Epoch 30/50
# 800/800 - 15s - loss: 6.8422e-04 - accuracy: 0.0045 - val_loss: 6.7806e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 31.56
#
# Epoch 00030: loss did not improve from 0.00068
# Epoch 31/50
# 800/800 - 15s - loss: 6.7143e-04 - accuracy: 0.0045 - val_loss: 6.7589e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 31.60
#
# Epoch 00031: loss improved from 0.00068 to 0.00067, saving model to /home/cst2/Testing Code/checkpoint/dbsrcnn
# Epoch 32/50
# 800/800 - 15s - loss: 6.7159e-04 - accuracy: 0.0045 - val_loss: 6.7326e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 31.60
#
# Epoch 00032: loss did not improve from 0.00067
# Epoch 33/50
# 800/800 - 15s - loss: 6.7121e-04 - accuracy: 0.0045 - val_loss: 6.7065e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 31.64
#
# Epoch 00033: loss improved from 0.00067 to 0.00067, saving model to /home/cst2/Testing Code/checkpoint/dbsrcnn
# Epoch 34/50
# 800/800 - 15s - loss: 6.6661e-04 - accuracy: 0.0045 - val_loss: 6.7160e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 31.59
#
# Epoch 00034: loss improved from 0.00067 to 0.00067, saving model to /home/cst2/Testing Code/checkpoint/dbsrcnn
# Epoch 35/50
# 800/800 - 15s - loss: 6.6670e-04 - accuracy: 0.0045 - val_loss: 6.6489e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 31.70
#
# Epoch 00035: loss did not improve from 0.00067
# Epoch 36/50
# 800/800 - 15s - loss: 6.5771e-04 - accuracy: 0.0045 - val_loss: 6.6093e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 31.70
#
# Epoch 00036: loss improved from 0.00067 to 0.00066, saving model to /home/cst2/Testing Code/checkpoint/dbsrcnn
# Epoch 37/50
# 800/800 - 15s - loss: 6.5871e-04 - accuracy: 0.0045 - val_loss: 6.5809e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 31.69
#
# Epoch 00037: loss did not improve from 0.00066
# Epoch 38/50
# 800/800 - 15s - loss: 6.5307e-04 - accuracy: 0.0045 - val_loss: 6.5606e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 31.70
#
# Epoch 00038: loss improved from 0.00066 to 0.00065, saving model to /home/cst2/Testing Code/checkpoint/dbsrcnn
# Epoch 39/50
# 800/800 - 15s - loss: 6.5205e-04 - accuracy: 0.0045 - val_loss: 6.5394e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 31.75
#
# Epoch 00039: loss improved from 0.00065 to 0.00065, saving model to /home/cst2/Testing Code/checkpoint/dbsrcnn
# Epoch 40/50
# 800/800 - 15s - loss: 6.5410e-04 - accuracy: 0.0045 - val_loss: 6.5089e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 31.75
#
# Epoch 00040: loss did not improve from 0.00065
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 8.100000122794882e-05.
# Epoch 41/50
# 800/800 - 15s - loss: 6.4276e-04 - accuracy: 0.0045 - val_loss: 6.4926e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 31.81
#
# Epoch 00041: loss improved from 0.00065 to 0.00064, saving model to /home/cst2/Testing Code/checkpoint/dbsrcnn
# Epoch 42/50
# 800/800 - 15s - loss: 6.4242e-04 - accuracy: 0.0045 - val_loss: 6.5537e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 31.75
#
# Epoch 00042: loss improved from 0.00064 to 0.00064, saving model to /home/cst2/Testing Code/checkpoint/dbsrcnn
# Epoch 43/50
# 800/800 - 15s - loss: 6.4223e-04 - accuracy: 0.0045 - val_loss: 6.4412e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 31.84
#
# Epoch 00043: loss improved from 0.00064 to 0.00064, saving model to /home/cst2/Testing Code/checkpoint/dbsrcnn
# Epoch 44/50
# 800/800 - 15s - loss: 6.4240e-04 - accuracy: 0.0045 - val_loss: 6.5055e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 31.77
#
# Epoch 00044: loss did not improve from 0.00064
# Epoch 45/50
# 800/800 - 15s - loss: 6.3406e-04 - accuracy: 0.0045 - val_loss: 6.4005e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 31.85
#
# Epoch 00045: loss improved from 0.00064 to 0.00063, saving model to /home/cst2/Testing Code/checkpoint/dbsrcnn
# Epoch 46/50
# 800/800 - 15s - loss: 6.3505e-04 - accuracy: 0.0045 - val_loss: 6.3832e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 31.85
#
# Epoch 00046: loss did not improve from 0.00063
# Epoch 47/50
# 800/800 - 15s - loss: 6.3193e-04 - accuracy: 0.0045 - val_loss: 6.3522e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 31.87
#
# Epoch 00047: loss improved from 0.00063 to 0.00063, saving model to /home/cst2/Testing Code/checkpoint/dbsrcnn
# Epoch 48/50
# 800/800 - 15s - loss: 6.2777e-04 - accuracy: 0.0045 - val_loss: 6.3244e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 31.88
#
# Epoch 00048: loss improved from 0.00063 to 0.00063, saving model to /home/cst2/Testing Code/checkpoint/dbsrcnn
# Epoch 49/50
# 800/800 - 15s - loss: 6.2674e-04 - accuracy: 0.0045 - val_loss: 6.3107e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 31.89
#
# Epoch 00049: loss improved from 0.00063 to 0.00063, saving model to /home/cst2/Testing Code/checkpoint/dbsrcnn
# Epoch 50/50
# 800/800 - 15s - loss: 6.2383e-04 - accuracy: 0.0045 - val_loss: 6.2851e-04 - val_accuracy: 0.0042
# mean PSNR for epoch: 31.89
#
# Epoch 00050: loss improved from 0.00063 to 0.00062, saving model to /home/cst2/Testing Code/checkpoint/dbsrcnn
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 7.289999848580919e-05.

# %%
total_bicubic_psnr=0.
total_test_psnr=0.
n_img=10

for index,test_path in enumerate(test_paths[0:n_img]):
    
    img=load_img(test_path)
    lowres_input=low_resolution_img(img,upscale_factor)
    
    w=lowres_input.size[0]*upscale_factor
    h=lowres_input.size[1]*upscale_factor
    
    highres_img=img.resize((w,h))
    
    predict_img=upscale_img(model,lowres_input)
    
    lowres_img=lowres_input.resize((w,h))
    lowres_img_arr=img_to_array(lowres_img)
    
    highres_img_arr=img_to_array(highres_img)
    
    predict_img_arr=img_to_array(predict_img)
    
    bicubic_psnr=tf.image.psnr(lowres_img_arr,highres_img_arr,max_val=255)
    test_psnr=tf.image.psnr(predict_img_arr,highres_img_arr,max_val=255)
    
    total_bicubic_psnr+=bicubic_psnr
    total_test_psnr+=test_psnr
    
    print('PSNR of low resolution and high resolution is %.4f'%bicubic_psnr)
    print('PSNR of predict and high resolution is %.4f'%test_psnr)
    
    display_results(lowres_img,index,'low resolution')
    display_results(highres_img,index,'high resolution')
    display_results(predict_img,index,'prediction')
    
print('avg. PSNR of images with low resolution is %.4f'%(total_bicubic_psnr/n_img))

print('avg. PSNR of reconstructions is %.4f'%(total_test_psnr/n_img))
# Out:
# PSNR of low resolution and high resolution is 31.1799
# PSNR of predict and high resolution is 31.3423
# PSNR of low resolution and high resolution is 32.8316
# PSNR of predict and high resolution is 32.7632
# PSNR of low resolution and high resolution is 33.4500
# PSNR of predict and high resolution is 33.0899
# PSNR of low resolution and high resolution is 28.3846
# PSNR of predict and high resolution is 28.6169
# PSNR of low resolution and high resolution is 25.0418
# PSNR of predict and high resolution is 25.2311
# PSNR of low resolution and high resolution is 29.5121
# PSNR of predict and high resolution is 29.9854
# PSNR of low resolution and high resolution is 31.8701
# PSNR of predict and high resolution is 31.7978
# PSNR of low resolution and high resolution is 28.5984
# PSNR of predict and high resolution is 28.6769
# PSNR of low resolution and high resolution is 32.0471
# PSNR of predict and high resolution is 31.9369
# PSNR of low resolution and high resolution is 28.1478
# PSNR of predict and high resolution is 28.3937
# avg. PSNR of images with low resolution is 30.1063
# avg. PSNR of reconstructions is 30.1834
